# %%
import pandas as pd

# %%
drivers_df = pd.read_csv("drivers.csv")
laps_df = pd.read_csv("lap_times.csv")

# %%
Drivers_merge = drivers_df.merge(laps_df, left_on='driverId', right_on='driverId')
Drivers_merge
# Out:
#         driverId driverRef number code  forename   surname         dob  \
# 0              1  hamilton     44  HAM     Lewis  Hamilton  1985-01-07
# 1              1  hamilton     44  HAM     Lewis  Hamilton  1985-01-07
# 2              1  hamilton     44  HAM     Lewis  Hamilton  1985-01-07
# 3              1  hamilton     44  HAM     Lewis  Hamilton  1985-01-07
# 4              1  hamilton     44  HAM     Lewis  Hamilton  1985-01-07
# ...          ...       ...    ...  ...       ...       ...         ...
# 485105       849    latifi      6  LAT  Nicholas    Latifi  1995-06-29
# 485106       849    latifi      6  LAT  Nicholas    Latifi  1995-06-29
# 485107       849    latifi      6  LAT  Nicholas    Latifi  1995-06-29
# 485108       849    latifi      6  LAT  Nicholas    Latifi  1995-06-29
# 485109       849    latifi      6  LAT  Nicholas    Latifi  1995-06-29
#
#        nationality                                           url  raceId  lap  \
# 0          British   http://en.wikipedia.org/wiki/Lewis_Hamilton     841    1
# 1          British   http://en.wikipedia.org/wiki/Lewis_Hamilton     841    2
# 2          British   http://en.wikipedia.org/wiki/Lewis_Hamilton     841    3
# 3          British   http://en.wikipedia.org/wiki/Lewis_Hamilton     841    4
# 4          British   http://en.wikipedia.org/wiki/Lewis_Hamilton     841    5
# ...            ...                                           ...     ...  ...
# 485105    Canadian  http://en.wikipedia.org/wiki/Nicholas_Latifi    1042   60
# 485106    Canadian  http://en.wikipedia.org/wiki/Nicholas_Latifi    1042   61
# 485107    Canadian  http://en.wikipedia.org/wiki/Nicholas_Latifi    1042   62
# 485108    Canadian  http://en.wikipedia.org/wiki/Nicholas_Latifi    1042   63
# 485109    Canadian  http://en.wikipedia.org/wiki/Nicholas_Latifi    1042   64
#
#         position      time  milliseconds
# 0              2  1:40.573        100573
# 1              2  1:33.774         93774
# 2              2  1:32.900         92900
# 3              2  1:32.582         92582
# 4              2  1:32.471         92471
# ...          ...       ...           ...
# 485105        18  1:22.851         82851
# 485106        18  1:22.552         82552
# 485107        18  1:22.453         82453
# 485108        18  1:23.571         83571
# 485109        18  1:22.743         82743
#
# [485110 rows x 14 columns]

# %%
constructors_df = pd.read_csv("constructors.csv")
constructors_df
# Out:
#      constructorId constructorRef                  name nationality  \
# 0                1        mclaren               McLaren     British
# 1                2     bmw_sauber            BMW Sauber      German
# 2                3       williams              Williams     British
# 3                4        renault               Renault      French
# 4                5     toro_rosso            Toro Rosso     Italian
# ..             ...            ...                   ...         ...
# 206            209          manor        Manor Marussia     British
# 207            210           haas          Haas F1 Team    American
# 208            211   racing_point          Racing Point     British
# 209            212    alpha_tauri  Scuderia Alpha Tauri     Italian
# 210            213     alphatauri            AlphaTauri     Italian
#
#                                                    url
# 0                 http://en.wikipedia.org/wiki/McLaren
# 1              http://en.wikipedia.org/wiki/BMW_Sauber
# 2    http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# 3    http://en.wikipedia.org/wiki/Renault_in_Formul...
# 4     http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso
# ..                                                 ...
# 206      http://en.wikipedia.org/wiki/Manor_Motorsport
# 207          http://en.wikipedia.org/wiki/Haas_F1_Team
# 208  http://en.wikipedia.org/wiki/Racing_Point_F1_Team
# 209  http://en.wikipedia.org/wiki/Scuderia_Alpha_Tauri
# 210   http://en.wikipedia.org/wiki/Scuderia_AlphaTauri
#
# [211 rows x 5 columns]

# %%
constructors_standings = pd.read_csv("constructor_standings.csv")
constructors_standings
# Out:
#        constructorStandingsId  raceId  constructorId  points  position  \
# 0                           1      18              1    14.0         1
# 1                           2      18              2     8.0         3
# 2                           3      18              3     9.0         2
# 3                           4      18              4     5.0         4
# 4                           5      18              5     2.0         5
# ...                       ...     ...            ...     ...       ...
# 12431                   27608    1042              4   120.0         5
# 12432                   27609    1042             51     5.0         8
# 12433                   27610    1042              3     0.0        10
# 12434                   27611    1042              9   226.0         2
# 12435                   27612    1042            210     3.0         9
#
#       positionText  wins
# 0                1     1
# 1                3     0
# 2                2     0
# 3                4     0
# 4                5     0
# ...            ...   ...
# 12431            5     0
# 12432            8     0
# 12433           10     0
# 12434            2     1
# 12435            9     0
#
# [12436 rows x 7 columns]

# %%
Constructor_merge = constructors_df.merge(constructors_standings, left_on='constructorId', right_on='constructorId')
Constructor_merge
# Out:
#        constructorId constructorRef        name nationality  \
# 0                  1        mclaren     McLaren     British
# 1                  1        mclaren     McLaren     British
# 2                  1        mclaren     McLaren     British
# 3                  1        mclaren     McLaren     British
# 4                  1        mclaren     McLaren     British
# ...              ...            ...         ...         ...
# 12431            213     alphatauri  AlphaTauri     Italian
# 12432            213     alphatauri  AlphaTauri     Italian
# 12433            213     alphatauri  AlphaTauri     Italian
# 12434            213     alphatauri  AlphaTauri     Italian
# 12435            213     alphatauri  AlphaTauri     Italian
#
#                                                     url  \
# 0                  http://en.wikipedia.org/wiki/McLaren
# 1                  http://en.wikipedia.org/wiki/McLaren
# 2                  http://en.wikipedia.org/wiki/McLaren
# 3                  http://en.wikipedia.org/wiki/McLaren
# 4                  http://en.wikipedia.org/wiki/McLaren
# ...                                                 ...
# 12431  http://en.wikipedia.org/wiki/Scuderia_AlphaTauri
# 12432  http://en.wikipedia.org/wiki/Scuderia_AlphaTauri
# 12433  http://en.wikipedia.org/wiki/Scuderia_AlphaTauri
# 12434  http://en.wikipedia.org/wiki/Scuderia_AlphaTauri
# 12435  http://en.wikipedia.org/wiki/Scuderia_AlphaTauri
#
#        constructorStandingsId  raceId  points  position positionText  wins
# 0                           1      18    14.0         1            1     1
# 1                           7      19    24.0         1            1     1
# 2                          18      20    28.0         3            3     1
# 3                          29      21    34.0         3            3     1
# 4                          40      22    42.0         3            3     1
# ...                       ...     ...     ...       ...          ...   ...
# 12431                   27557    1038    47.0         7            7     1
# 12432                   27567    1039    53.0         7            7     1
# 12433                   27587    1040    59.0         7            7     1
# 12434                   27597    1041    67.0         7            7     1
# 12435                   27607    1042    77.0         7            7     1
#
# [12436 rows x 11 columns]

# %%
Races_df = pd.read_csv("races.csv")

# %%
Constructor_Final = Constructor_merge.merge(Races_df, left_on='raceId', right_on='raceId')
Constructor_Final.rename(columns={"name_x":"Constructor_Names","name_y":"Race_Name"},inplace=True)

# %%
Constructor_Final.drop(columns=["url_x","url_y"],inplace=True)

# %%
Constructor_Final
# Out:
#        constructorId  constructorRef Constructor_Names    nationality  \
# 0                  1         mclaren           McLaren        British
# 1                  2      bmw_sauber        BMW Sauber         German
# 2                  3        williams          Williams        British
# 3                  4         renault           Renault         French
# 4                  5      toro_rosso        Toro Rosso        Italian
# ...              ...             ...               ...            ...
# 12431            176       lotus-brm         Lotus-BRM        British
# 12432            183  brabham-climax    Brabham-Climax        British
# 12433            184      lds-climax        LDS-Climax  South African
# 12434            189    eagle-climax      Eagle-Climax       American
# 12435            191   brabham-repco     Brabham-Repco        British
#
#        constructorStandingsId  raceId  points  position positionText  wins  \
# 0                           1      18    14.0         1            1     1
# 1                           2      18     8.0         3            3     0
# 2                           3      18     9.0         2            2     0
# 3                           4      18     5.0         4            4     0
# 4                           5      18     2.0         5            5     0
# ...                       ...     ...     ...       ...          ...   ...
# 12431                   20741     679     0.0         7            7     0
# 12432                   20739     679     2.0         5            5     0
# 12433                   20740     679     0.0         6            6     0
# 12434                   20742     679     0.0         8            8     0
# 12435                   20738     679     3.0         4            4     0
#
#        year  round  circuitId                 Race_Name        date      time
# 0      2008      1          1     Australian Grand Prix  2008-03-16  04:30:00
# 1      2008      1          1     Australian Grand Prix  2008-03-16  04:30:00
# 2      2008      1          1     Australian Grand Prix  2008-03-16  04:30:00
# 3      2008      1          1     Australian Grand Prix  2008-03-16  04:30:00
# 4      2008      1          1     Australian Grand Prix  2008-03-16  04:30:00
# ...     ...    ...        ...                       ...         ...       ...
# 12431  1967      1         30  South African Grand Prix  1967-01-02        \N
# 12432  1967      1         30  South African Grand Prix  1967-01-02        \N
# 12433  1967      1         30  South African Grand Prix  1967-01-02        \N
# 12434  1967      1         30  South African Grand Prix  1967-01-02        \N
# 12435  1967      1         30  South African Grand Prix  1967-01-02        \N
#
# [12436 rows x 16 columns]

# %%
Constructor_Final.to_csv("../Modified/constructor_final.csv")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-47-aac8ef33358e> in <module>
# ----> 1 Constructor_Final.to_csv("../Modified/constructor_final.csv")
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     186                 self.mode,
#     187                 encoding=self.encoding,
# --> 188                 compression=dict(self.compression_args, method=self.compression),
#     189             )
#     190             close = True
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     426         if encoding:
#     427             # Encoding
# --> 428             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     429         elif is_text:
#     430             # No explicit encoding
#
# PermissionError: [Errno 13] Permission denied: '../Modified/constructor_final.csv'

# %%
driver_standings = pd.read_csv("driver_standings.csv")

# %%
Drivers_merge = drivers_df.merge(driver_standings, left_on='driverId', right_on='driverId')
Drivers_merge
# Out:
#        driverId driverRef number code  forename   surname         dob  \
# 0             1  hamilton     44  HAM     Lewis  Hamilton  1985-01-07
# 1             1  hamilton     44  HAM     Lewis  Hamilton  1985-01-07
# 2             1  hamilton     44  HAM     Lewis  Hamilton  1985-01-07
# 3             1  hamilton     44  HAM     Lewis  Hamilton  1985-01-07
# 4             1  hamilton     44  HAM     Lewis  Hamilton  1985-01-07
# ...         ...       ...    ...  ...       ...       ...         ...
# 32810       849    latifi      6  LAT  Nicholas    Latifi  1995-06-29
# 32811       849    latifi      6  LAT  Nicholas    Latifi  1995-06-29
# 32812       849    latifi      6  LAT  Nicholas    Latifi  1995-06-29
# 32813       849    latifi      6  LAT  Nicholas    Latifi  1995-06-29
# 32814       849    latifi      6  LAT  Nicholas    Latifi  1995-06-29
#
#       nationality                                           url  \
# 0         British   http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1         British   http://en.wikipedia.org/wiki/Lewis_Hamilton
# 2         British   http://en.wikipedia.org/wiki/Lewis_Hamilton
# 3         British   http://en.wikipedia.org/wiki/Lewis_Hamilton
# 4         British   http://en.wikipedia.org/wiki/Lewis_Hamilton
# ...           ...                                           ...
# 32810    Canadian  http://en.wikipedia.org/wiki/Nicholas_Latifi
# 32811    Canadian  http://en.wikipedia.org/wiki/Nicholas_Latifi
# 32812    Canadian  http://en.wikipedia.org/wiki/Nicholas_Latifi
# 32813    Canadian  http://en.wikipedia.org/wiki/Nicholas_Latifi
# 32814    Canadian  http://en.wikipedia.org/wiki/Nicholas_Latifi
#
#        driverStandingsId  raceId  points  position positionText  wins
# 0                      1      18    10.0         1            1     1
# 1                      9      19    14.0         1            1     1
# 2                     27      20    14.0         3            3     1
# 3                     48      21    20.0         2            2     1
# 4                     69      22    28.0         3            3     1
# ...                  ...     ...     ...       ...          ...   ...
# 32810              69963    1038     0.0        18           18     0
# 32811              69984    1039     0.0        19           19     0
# 32812              70025    1040     0.0        19           19     0
# 32813              70046    1041     0.0        20           20     0
# 32814              70067    1042     0.0        20           20     0
#
# [32815 rows x 15 columns]

# %%
Drivers_New = Drivers_merge.merge(Races_df, left_on='raceId', right_on='raceId')
Drivers_New
# Out:
#        driverId       driverRef number code  forename     surname         dob  \
# 0             1        hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1             2        heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2             3         rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3             4          alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4             5      kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
# ...         ...             ...    ...  ...       ...         ...         ...
# 32810       786         fagioli     \N   \N     Luigi     Fagioli  1898-06-09
# 32811       787        harrison     \N   \N      Cuth    Harrison  1906-07-06
# 32812       788             fry     \N   \N       Joe         Fry  1915-10-26
# 32813       789          martin     \N   \N    Eugène      Martin  1915-03-24
# 32814       790  leslie_johnson     \N   \N    Leslie     Johnson  1912-03-22
#
#       nationality                                              url_x  \
# 0         British        http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1          German         http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2          German          http://en.wikipedia.org/wiki/Nico_Rosberg
# 3         Spanish       http://en.wikipedia.org/wiki/Fernando_Alonso
# 4         Finnish     http://en.wikipedia.org/wiki/Heikki_Kovalainen
# ...           ...                                                ...
# 32810     Italian         http://en.wikipedia.org/wiki/Luigi_Fagioli
# 32811     British         http://en.wikipedia.org/wiki/Cuth_Harrison
# 32812     British               http://en.wikipedia.org/wiki/Joe_Fry
# 32813      French    http://en.wikipedia.org/wiki/Eug%C3%A8ne_Martin
# 32814     British  http://en.wikipedia.org/wiki/Leslie_Johnson_(r...
#
#        driverStandingsId  ...  position  positionText  wins  year  round  \
# 0                      1  ...         1             1     1  2008      1
# 1                      2  ...         2             2     0  2008      1
# 2                      3  ...         3             3     0  2008      1
# 3                      4  ...         4             4     0  2008      1
# 4                      5  ...         5             5     0  2008      1
# ...                  ...  ...       ...           ...   ...   ...    ...
# 32810              43202  ...         2             2     0  1950      1
# 32811              43207  ...         7             7     0  1950      1
# 32812              43222  ...        10            10     0  1950      1
# 32813              43219  ...        20            20     0  1950      1
# 32814              43221  ...        23            23     0  1950      1
#
#        circuitId                   name        date      time  \
# 0              1  Australian Grand Prix  2008-03-16  04:30:00
# 1              1  Australian Grand Prix  2008-03-16  04:30:00
# 2              1  Australian Grand Prix  2008-03-16  04:30:00
# 3              1  Australian Grand Prix  2008-03-16  04:30:00
# 4              1  Australian Grand Prix  2008-03-16  04:30:00
# ...          ...                    ...         ...       ...
# 32810          9     British Grand Prix  1950-05-13        \N
# 32811          9     British Grand Prix  1950-05-13        \N
# 32812          9     British Grand Prix  1950-05-13        \N
# 32813          9     British Grand Prix  1950-05-13        \N
# 32814          9     British Grand Prix  1950-05-13        \N
#
#                                                    url_y
# 0      http://en.wikipedia.org/wiki/2008_Australian_G...
# 1      http://en.wikipedia.org/wiki/2008_Australian_G...
# 2      http://en.wikipedia.org/wiki/2008_Australian_G...
# 3      http://en.wikipedia.org/wiki/2008_Australian_G...
# 4      http://en.wikipedia.org/wiki/2008_Australian_G...
# ...                                                  ...
# 32810  http://en.wikipedia.org/wiki/1950_British_Gran...
# 32811  http://en.wikipedia.org/wiki/1950_British_Gran...
# 32812  http://en.wikipedia.org/wiki/1950_British_Gran...
# 32813  http://en.wikipedia.org/wiki/1950_British_Gran...
# 32814  http://en.wikipedia.org/wiki/1950_British_Gran...
#
# [32815 rows x 22 columns]

# %%
Drivers_New.drop(columns=["url_x","url_y"],inplace=True)

# %%
Drivers_New.columns
# Out:
# Index(['driverId', 'driverRef', 'number', 'code', 'forename', 'surname', 'dob',
#        'nationality', 'driverStandingsId', 'raceId', 'points', 'position',
#        'positionText', 'wins', 'year', 'round', 'circuitId', 'name', 'date',
#        'time'],
#       dtype='object')

# %%
Drivers_New.to_csv("../Modified/Driver_Info.csv",header=True,index=False)
